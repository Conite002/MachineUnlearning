# %%
import sys
import os
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
import warnings
import time
# Append the system path to include the parent directory for custom modules
sys.path.append('../')

# Import necessary modules from the custom packages
from Unlearner.DPLRUnlearner import DPLRUnlearner
from Applications.FeatureUnlearning.LinearEnsembleExperiments import split_train_data, create_models
from Applications.FeatureUnlearning.DataLoader import DataLoader
from Applications.FeatureUnlearning.LRExperiments import get_average_gradient_residual, scatter_experiments, find_most_relevant_indices

# %%
# Suppress warnings for cleaner output
warnings.filterwarnings("ignore")

# List of datasets to be used for the comparative study
datasets_name = ['Adult', 'Diabetis', 'Drebin', 'Enron']

# Unlearning parameters
lambda_ = 1.0  # Regularization strength
sigma = 0.0  # Noise to compute gradient residual
combination_lengths = [10, 50, 100]  # Number of features to remove
n_combinations = 10  # Number of combinations of features to remove
unlearning_rate = 0.0001  # First Order update unlearning rate
unlearning_rate_ft = unlearning_rate  # Learning rate for fine-tuning
iter_steps = 10  # Number of steps for iterative unlearning
remove = True  # Flag to actually remove the features

csv_file = 'unlearning_performance_metrics.csv'

# Function to perform unlearning and save results
def perform_unlearning(dataset_name, normalize=True):
    # Check if the dataset is supported
    supported_datasets = ['Adult', 'Diabetis', 'Enron', 'Drebin']
    if dataset_name not in supported_datasets:
        print(f"Dataset {dataset_name} is not supported. Skipping...")
        return

    # Load the training and test data
    loader = DataLoader(dataset_name, normalize)
    train_data, test_data, voc = (loader.x_train, loader.y_train), (loader.x_test, loader.y_test), loader.voc
    category_to_idx_dict = loader.category_to_idx_dict

    # Create folders for results
    res_save_folder = f'Results_{dataset_name}'
    model_save_folder = f'Models_{dataset_name}'
    if not os.path.isdir(res_save_folder):
        os.makedirs(res_save_folder)

    # Identify relevant features to be deleted
    relevant_features = loader.relevant_features
    relevant_indices = [voc[f] for f in relevant_features]
    indices_to_delete = relevant_indices

    print(f"Dataset: {dataset_name}")
    print(f"Relevant features: {', '.join(relevant_features[:10])}...")
    print(f"Number of relevant features: {len(relevant_features)}")

    # Check if combination lengths exceed the number of available features
    actual_combination_lengths = [cl for cl in combination_lengths if cl <= len(indices_to_delete)]

    if not actual_combination_lengths:
        print(f"Not enough features to remove for dataset {dataset_name}. Skipping...")
        return

    start_time = time.time()
    # Perform unlearning and get gradient residuals
    get_average_gradient_residual(train_data, test_data, voc, lambda_, sigma, indices_to_delete,
                                  actual_combination_lengths, n_combinations, unlearning_rate, unlearning_rate_ft,
                                  iter_steps, category_to_idx_dict, remove=remove, save_path=res_save_folder)

    gradient_residual_time = time.time() - start_time
    print(f"Time taken for get_average_gradient_residual: {gradient_residual_time:.2f} seconds")

    # Additional fidelity evaluation
    combination_length = 20
    most_important_size = 300
    top_indices, _ = find_most_relevant_indices(train_data, test_data, voc, top_n=most_important_size)
    indices_to_delete = np.intersect1d(top_indices, relevant_indices)

    # Check if combination length for scatter experiments exceeds the number of available features
    if combination_length > len(indices_to_delete):
        print(f"Not enough features to remove for scatter experiments in dataset {dataset_name}. Skipping scatter experiments...")
        return
    
    start_time = time.time()
    scatter_experiments(train_data, test_data, voc, lambda_, sigma, indices_to_delete, combination_length,
                        unlearning_rate, unlearning_rate_ft, n_combinations, category_to_idx_dict, remove)
    scatter_experiments_time = time.time() - start_time
    print(f"Time taken for scatter_experiments: {scatter_experiments_time:.2f} seconds")

    # Save the times to the CSV file
    performance_metrics = pd.DataFrame({
        'Dataset': [dataset_name],
        'Gradient_Residual_Time': [gradient_residual_time],
        'Scatter_Experiments_Time': [scatter_experiments_time]
    })
    if os.path.isfile(csv_file):
        existing_data = pd.read_csv(csv_file)
        combined_data = pd.concat([existing_data, performance_metrics], ignore_index=True)
        combined_data.to_csv(csv_file, index=False)
    else:
        performance_metrics.to_csv(csv_file, index=False)

# Iterate through each dataset and perform unlearning
for dataset_name in datasets_name:
    perform_unlearning(dataset_name)
# Out:
# Dataset: Adult
# Relevant features: marital-status_Never-married, marital-status_Divorced, marital-status_Separated, marital-status_Widowed, marital-status_Married-spouse-absent, marital-status_Married-AF-spouse, relationship_Not-in-family, relationship_Own-child, relationship_Unmarried, relationship_Wife...
# Number of relevant features: 15
#
# Sampling 10 combinations of 10 features ...
# 100%|██████████| 10/10 [00:29<00:00,  2.94s/it]
# Saved results in Results_Adult/grad_residual_lambda=1.0_sigma=0.0_comb_len=10_ULR=0.0001
# Gradient Residuals for methods [DP, Finetuning, First-Order, Second Order]
# Mean residual: [532.1610780253714, 533.2976428710058, 508.53769237860644, 88.52403563220517]
# Std residual: [232.25537043265902, 232.27166269010453, 219.4344524237636, 55.40887426083929]
# Sigmas for certification: [16846.298889246988, 16882.27842981695, 16098.46776853061, 2802.3514396732694]
# Retraining from scratch achieved accuracy of 0.8321663288495792
# SISA achieved accuracy of 0.8050549720533136
# Retraining model with resulting sigma from DP for 100 times ...
# 100%|██████████| 100/100 [00:20<00:00,  4.91it/s]
# DP achieved avg accuracy of 0.5303181622750445 (min 0.28628462625145873, max 0.7423991155334438).
# DP achieved avg macro f1 score of 0.4767998738002892.
# DP achieved weighted f1 score of 0.5583440279742953.
# Retraining model with resulting sigma from Finetuning for 100 times ...
# 100%|██████████| 100/100 [00:20<00:00,  4.88it/s]
# Finetuning achieved avg accuracy of 0.5390209446594189 (min 0.2910754867637123, max 0.762238191757263).
# Finetuning achieved avg macro f1 score of 0.48855442423212897.
# Finetuning achieved weighted f1 score of 0.5650102594656707.
# Retraining model with resulting sigma from 1st-Order for 100 times ...
# 100%|██████████| 100/100 [00:22<00:00,  4.46it/s]
# 1st-Order achieved avg accuracy of 0.5111000552791598 (min 0.2467907376696763, max 0.7854554388551072).
# 1st-Order achieved avg macro f1 score of 0.4665313317273369.
# 1st-Order achieved weighted f1 score of 0.5387506943952795.
# Retraining model with resulting sigma from 2nd-Order for 100 times ...
# 100%|██████████| 100/100 [00:20<00:00,  4.96it/s]
# 2nd-Order achieved avg accuracy of 0.6476936306123703 (min 0.36754499109391314, max 0.8027148209569437).
# 2nd-Order achieved avg macro f1 score of 0.5742626684119285.
# 2nd-Order achieved weighted f1 score of 0.6644528365994483.
# Time taken for get_average_gradient_residual: 114.28 seconds
# Not enough features to remove for scatter experiments in dataset Adult. Skipping scatter experiments...
# Dataset: Diabetis
# Relevant features: Pregnancies, BMI, Age...
# Number of relevant features: 3
# Not enough features to remove for dataset Diabetis. Skipping...
# Dataset: Drebin
# Relevant features: url::http://schemas.android.com/apk/res/, url::r.admob.com, url::http://r.admob.com/ad_source.php, url::http://mm.admob.com/static/android/canvas.html, url::http://mm.admob.com/static/android/i18n/20100820, url::http://api.admob.com/v1/pubcode/android_sdk_emulator_notice, url::http://a.admob.com/f0?, url::mm.admob.com, url::api.admob.com, url::a.admob.com...
# Number of relevant features: 1197
#
# Sampling 10 combinations of 10 features ...
# 100%|██████████| 10/10 [00:57<00:00,  5.77s/it]
# Saved results in Results_Drebin/grad_residual_lambda=1.0_sigma=0.0_comb_len=10_ULR=0.0001
# Gradient Residuals for methods [DP, Finetuning, First-Order, Second Order]
# Mean residual: [3.1903704152643546, 5.325119758849812, 3.1234793014110678, 0.047654837167912176]
# Std residual: [2.2431601611463217, 1.5183294799642482, 2.182748238733828, 0.048732248330610385]
# Sigmas for certification: [100.99561167153219, 168.574070489127, 98.87808045111964, 1.5085801340976128]
# Retraining from scratch achieved accuracy of 0.9773004265691652
# SISA achieved accuracy of 0.9599735933373958
# Retraining model with resulting sigma from DP for 100 times ...
# 100%|██████████| 100/100 [00:22<00:00,  4.42it/s]
# DP achieved avg accuracy of 0.950261019703433 (min 0.9120455007109486, max 0.9529758277473086).
# DP achieved avg macro f1 score of 0.49630373943130346.
# DP achieved weighted f1 score of 0.9293697629600668.
# Retraining model with resulting sigma from Finetuning for 100 times ...
# 100%|██████████| 100/100 [00:19<00:00,  5.11it/s]
# Finetuning achieved avg accuracy of 0.9528702010968925 (min 0.9527726995734308, max 0.9529758277473086).
# Finetuning achieved avg macro f1 score of 0.4879546900537882.
# Finetuning achieved weighted f1 score of 0.9298799750433485.
# Retraining model with resulting sigma from 1st-Order for 100 times ...
# 100%|██████████| 100/100 [00:24<00:00,  4.14it/s]
# 1st-Order achieved avg accuracy of 0.9489254519601872 (min 0.9092017062766605, max 0.9531789559211863).
# 1st-Order achieved avg macro f1 score of 0.5047382493672938.
# 1st-Order achieved weighted f1 score of 0.9294938672536499.
# Retraining model with resulting sigma from 2nd-Order for 100 times ...
# 100%|██████████| 100/100 [01:33<00:00,  1.08it/s]
# 2nd-Order achieved avg accuracy of 0.977284176315255 (min 0.9759293113954906, max 0.9783668494820231).
# 2nd-Order achieved avg macro f1 score of 0.8488198541563898.
# 2nd-Order achieved weighted f1 score of 0.9750450841627522.
# Sampling 10 combinations of 50 features ...
# 100%|██████████| 10/10 [00:42<00:00,  4.24s/it]
# Saved results in Results_Drebin/grad_residual_lambda=1.0_sigma=0.0_comb_len=50_ULR=0.0001
# Gradient Residuals for methods [DP, Finetuning, First-Order, Second Order]
# Mean residual: [4.42725862646356, 7.024341341743839, 4.361683312095202, 0.09746671101985963]
# Std residual: [2.7280812577781415, 3.2499990466098785, 2.638184220607533, 0.1022757547988311]
# Sigmas for certification: [140.15102787702637, 222.36529244528705, 138.0751501189145, 3.0854442637650705]
# Retraining from scratch achieved accuracy of 0.9771988624822263
# SISA achieved accuracy of 0.9555453991468618
# Retraining model with resulting sigma from DP for 100 times ...
# 100%|██████████| 100/100 [00:19<00:00,  5.02it/s]
# DP achieved avg accuracy of 0.9528610603290679 (min 0.9525695713995531, max 0.9528742636603696).
# DP achieved avg macro f1 score of 0.4879308002077012.
# DP achieved weighted f1 score of 0.9298734039302566.
# Retraining model with resulting sigma from Finetuning for 100 times ...
# 100%|██████████| 100/100 [00:20<00:00,  4.90it/s]
# Finetuning achieved avg accuracy of 0.9528681698151538 (min 0.952671135486492, max 0.9528742636603696).
# Finetuning achieved avg macro f1 score of 0.48803764349734174.
# Finetuning achieved weighted f1 score of 0.9298867370680841.
# Retraining model with resulting sigma from 1st-Order for 100 times ...
# 100%|██████████| 100/100 [00:19<00:00,  5.03it/s]
# 1st-Order achieved avg accuracy of 0.9528600446881985 (min 0.9522648791387366, max 0.9531789559211863).
# 1st-Order achieved avg macro f1 score of 0.48799473574878294.
# 1st-Order achieved weighted f1 score of 0.9298788787330472.
# Retraining model with resulting sigma from 2nd-Order for 100 times ...
# 100%|██████████| 100/100 [01:30<00:00,  1.10it/s]
# 2nd-Order achieved avg accuracy of 0.9754489132642697 (min 0.9729839528742636, max 0.9772496445256957).
# 2nd-Order achieved avg macro f1 score of 0.8385326047955337.
# 2nd-Order achieved weighted f1 score of 0.9732046302316245.
# Sampling 10 combinations of 100 features ...
# 100%|██████████| 10/10 [00:45<00:00,  4.53s/it]
# Saved results in Results_Drebin/grad_residual_lambda=1.0_sigma=0.0_comb_len=100_ULR=0.0001
# Gradient Residuals for methods [DP, Finetuning, First-Order, Second Order]
# Mean residual: [13.77769498907079, 16.8778195763714, 13.44754056397529, 0.7107765047978274]
# Std residual: [12.875858364912508, 13.450630116328375, 12.45718914143473, 1.091824176973315]
# Sigmas for certification: [436.1520926182829, 534.2908471197529, 425.70059521564656, 22.50061858659198]
# Retraining from scratch achieved accuracy of 0.9772090188909202
# SISA achieved accuracy of 0.9535547430428603
# Retraining model with resulting sigma from DP for 100 times ...
# 100%|██████████| 100/100 [00:19<00:00,  5.01it/s]
# DP achieved avg accuracy of 0.9528295754621168 (min 0.9518586227909811, max 0.9528742636603696).
# DP achieved avg macro f1 score of 0.48796435695403945.
# DP achieved weighted f1 score of 0.9298615597943298.
# Retraining model with resulting sigma from Finetuning for 100 times ...
# 100%|██████████| 100/100 [00:20<00:00,  4.83it/s]
# Finetuning achieved avg accuracy of 0.9528234816169006 (min 0.95196018687792, max 0.9529758277473086).
# Finetuning achieved avg macro f1 score of 0.4880488974332102.
# Finetuning achieved weighted f1 score of 0.9298665439317827.
# Retraining model with resulting sigma from 1st-Order for 100 times ...
# 100%|██████████| 100/100 [00:20<00:00,  4.94it/s]
# 1st-Order achieved avg accuracy of 0.9528204346942922 (min 0.9516554946171034, max 0.9528742636603696).
# 1st-Order achieved avg macro f1 score of 0.4879628544011219.
# 1st-Order achieved weighted f1 score of 0.9298570767581181.
# Retraining model with resulting sigma from 2nd-Order for 100 times ...
# 100%|██████████| 100/100 [01:15<00:00,  1.32it/s]
# 2nd-Order achieved avg accuracy of 0.9467276051188301 (min 0.9403818809668901, max 0.9554133658338412).
# 2nd-Order achieved avg macro f1 score of 0.703957988827476.
# 2nd-Order achieved weighted f1 score of 0.9467757212759074.
# Time taken for get_average_gradient_residual: 594.69 seconds
# 100%|██████████| 10/10 [00:26<00:00,  2.62s/it]
# Saved results at ./scatter_losses-combinations-20-lambda-1.0-sigma-0.0-top-140.npy
# Time taken for scatter_experiments: 27.20 seconds
# Dataset: Enron
# Relevant features: adams, afford, alan, allen, anderson, anthony, arnold, arthur, austin, barry...
# Number of relevant features: 308
#
# Sampling 10 combinations of 10 features ...
# 100%|██████████| 10/10 [01:06<00:00,  6.67s/it]
# Saved results in Results_Enron/grad_residual_lambda=1.0_sigma=0.0_comb_len=10_ULR=0.0001
# Gradient Residuals for methods [DP, Finetuning, First-Order, Second Order]
# Mean residual: [5.669747699654721, 5.517624920215903, 5.5967424136401425, 0.09482795275831178]
# Std residual: [6.62510317949212, 6.495967588635539, 6.516871175441743, 0.1757970701919147]
# Sigmas for certification: [179.48374715681527, 174.66808904856265, 177.17266331494528, 3.0019107018303037]
# Retraining from scratch achieved accuracy of 0.9843861209964413
# SISA achieved accuracy of 0.962158956109134
# Retraining model with resulting sigma from DP for 100 times ...
# 100%|██████████| 100/100 [00:32<00:00,  3.05it/s]
# DP achieved avg accuracy of 0.6314486951364175 (min 0.49362396204033215, max 0.8035290628706999).
# DP achieved avg macro f1 score of 0.5719014120935608.
# DP achieved weighted f1 score of 0.5717673908927117.
# Retraining model with resulting sigma from Finetuning for 100 times ...
# 100%|██████████| 100/100 [00:34<00:00,  2.91it/s]
# Finetuning achieved avg accuracy of 0.6476230723606169 (min 0.4916963226571768, max 0.8107947805456702).
# Finetuning achieved avg macro f1 score of 0.6000654403592425.
# Finetuning achieved weighted f1 score of 0.5984098592289547.
# Retraining model with resulting sigma from 1st-Order for 100 times ...
# 100%|██████████| 100/100 [00:33<00:00,  3.03it/s]
# 1st-Order achieved avg accuracy of 0.6551631079478055 (min 0.4959964412811388, max 0.7995255041518387).
# 1st-Order achieved avg macro f1 score of 0.6077451868683577.
# 1st-Order achieved weighted f1 score of 0.6074190710725237.
# Retraining model with resulting sigma from 2nd-Order for 100 times ...
# 100%|██████████| 100/100 [01:51<00:00,  1.12s/it]
# 2nd-Order achieved avg accuracy of 0.9558540925266903 (min 0.9494365361803084, max 0.9617437722419929).
# 2nd-Order achieved avg macro f1 score of 0.9557800843443306.
# 2nd-Order achieved weighted f1 score of 0.955843280187636.
# Sampling 10 combinations of 50 features ...
# 100%|██████████| 10/10 [01:08<00:00,  6.89s/it]
# Saved results in Results_Enron/grad_residual_lambda=1.0_sigma=0.0_comb_len=50_ULR=0.0001
# Gradient Residuals for methods [DP, Finetuning, First-Order, Second Order]
# Mean residual: [14.264384668739137, 14.063333755010586, 14.051987186054333, 0.3201783892425099]
# Std residual: [10.189424657023668, 10.098017253585063, 10.01267181416248, 0.40397831006266516]
# Sigmas for certification: [451.5589311650395, 445.19438493179183, 444.8351935141975, 10.135692116137491]
# Retraining from scratch achieved accuracy of 0.9839857651245552
# SISA achieved accuracy of 0.9481613285883748
# Retraining model with resulting sigma from DP for 100 times ...
# 100%|██████████| 100/100 [00:34<00:00,  2.91it/s]
# DP achieved avg accuracy of 0.592293890865955 (min 0.4989620403321471, max 0.6938018979833926).
# DP achieved avg macro f1 score of 0.5584501673996326.
# DP achieved weighted f1 score of 0.558513134227797.
# Retraining model with resulting sigma from Finetuning for 100 times ...
# 100%|██████████| 100/100 [00:34<00:00,  2.90it/s]
# Finetuning achieved avg accuracy of 0.5923798932384341 (min 0.4918446026097272, max 0.7099644128113879).
# Finetuning achieved avg macro f1 score of 0.5566098278520442.
# Finetuning achieved weighted f1 score of 0.555722417129216.
# Retraining model with resulting sigma from 1st-Order for 100 times ...
# 100%|██████████| 100/100 [00:34<00:00,  2.89it/s]
# 1st-Order achieved avg accuracy of 0.5972879596678529 (min 0.4891755634638197, max 0.7279062870699882).
# 1st-Order achieved avg macro f1 score of 0.5675303281707831.
# 1st-Order achieved weighted f1 score of 0.5671941403448514.
# Retraining model with resulting sigma from 2nd-Order for 100 times ...
# 100%|██████████| 100/100 [01:36<00:00,  1.04it/s]
# 2nd-Order achieved avg accuracy of 0.8962485172004745 (min 0.886417556346382, max 0.908214709371293).
# 2nd-Order achieved avg macro f1 score of 0.8961396591529127.
# 2nd-Order achieved weighted f1 score of 0.896256508260428.
# Sampling 10 combinations of 100 features ...
# 100%|██████████| 10/10 [01:10<00:00,  7.07s/it]
# Saved results in Results_Enron/grad_residual_lambda=1.0_sigma=0.0_comb_len=100_ULR=0.0001
# Gradient Residuals for methods [DP, Finetuning, First-Order, Second Order]
# Mean residual: [26.51916236981442, 26.189356956058113, 26.096372661568033, 0.8789475020111059]
# Std residual: [13.040597095759743, 13.007896623290128, 12.790212275144176, 0.6094848886503755]
# Sigmas for certification: [839.5009594314334, 829.0605104680359, 826.1169633322738, 27.82430534337231]
# Retraining from scratch achieved accuracy of 0.9831257413997626
# SISA achieved accuracy of 0.916429418742586
# Retraining model with resulting sigma from DP for 100 times ...
# 100%|██████████| 100/100 [00:39<00:00,  2.54it/s]
# DP achieved avg accuracy of 0.559988137603796 (min 0.4676749703440095, max 0.6497627520759194).
# DP achieved avg macro f1 score of 0.5402343108744116.
# DP achieved weighted f1 score of 0.5404655095834061.
# Retraining model with resulting sigma from Finetuning for 100 times ...
# 100%|██████████| 100/100 [00:39<00:00,  2.55it/s]
# Finetuning achieved avg accuracy of 0.5604196322657177 (min 0.447508896797153, max 0.6626631079478055).
# Finetuning achieved avg macro f1 score of 0.5375518674975721.
# Finetuning achieved weighted f1 score of 0.5371580135191962.
# Retraining model with resulting sigma from 1st-Order for 100 times ...
# 100%|██████████| 100/100 [00:39<00:00,  2.55it/s]
# 1st-Order achieved avg accuracy of 0.5608733689205219 (min 0.48413404507710556, max 0.6706702253855279).
# 1st-Order achieved avg macro f1 score of 0.542142423917162.
# 1st-Order achieved weighted f1 score of 0.5419477045047423.
# Retraining model with resulting sigma from 2nd-Order for 100 times ...
# 100%|██████████| 100/100 [01:24<00:00,  1.18it/s]
# 2nd-Order achieved avg accuracy of 0.8354522538552789 (min 0.8179122182680901, max 0.8572064056939501).
# 2nd-Order achieved avg macro f1 score of 0.8353256583300925.
# 2nd-Order achieved weighted f1 score of 0.8354818083074841.
# Time taken for get_average_gradient_residual: 823.35 seconds
# Not enough features to remove for scatter experiments in dataset Enron. Skipping scatter experiments...

# %%
import pandas as pd

# List of paths to the CSV files
folders = ['Results_Adult/fidelity_results.csv', 'Results_Drebin/fidelity_results.csv', 'Results_Enron/fidelity_results.csv']

# Initialize an empty list to store individual DataFrames
dfs = []

# Iterate over the file paths and read each CSV into a DataFrame
for f in folders:
    df = pd.read_csv(f)
    
    # Extract dataset name from the file path
    dataset_name = f.split('_')[1].split('/')[0]
    
    # Update the dataset name with the combination type
    df['Datasets'] = dataset_name + '_' + df['x'].astype(str)
    
    # Append the DataFrame to the list
    dfs.append(df)

# Combine all the DataFrames into a single DataFrame
combined_df = pd.concat(dfs, ignore_index=True)

# Display the combined DataFrame
print(combined_df)
# Out:
#      x         DP  Finetuning  1st-Order  2nd-Order  Retraining       SISA  \
# 0   10  53.031816   53.902094  51.110006  64.769363   83.216633  80.505497
# 1   10  95.026102   95.287020  94.892545  97.728418   97.730043  95.997359
# 2   50  95.286106   95.286817  95.286004  97.544891   97.719886  95.554540
# 3  100  95.282958   95.282348  95.282043  94.672761   97.720902  95.355474
# 4   10  63.144870   64.762307  65.516311  95.585409   98.438612  96.215896
# 5   50  59.229389   59.237989  59.728796  89.624852   98.398577  94.816133
# 6  100  55.998814   56.041963  56.087337  83.545225   98.312574  91.642942
#
#      Datasets
# 0    Adult_10
# 1   Drebin_10
# 2   Drebin_50
# 3  Drebin_100
# 4    Enron_10
# 5    Enron_50
# 6   Enron_100

# %%
# Regrouper par 'x'
grouped_df = combined_df.groupby('x')

# Créer les sous-graphes
fig, axs = plt.subplots(1, len(grouped_df), figsize=(20, 8), sharey=True)

# Couleurs des barres pour chaque méthode
colors = ['b', 'g', 'r', 'c', 'm', 'y']

# Tracer les barres pour chaque groupe de 'x'
for (x_value, group), ax in zip(grouped_df, axs):
    group = group.set_index('Datasets')
    group.drop('x', axis=1, inplace=True)
    group.plot(kind='bar', ax=ax, color=colors, legend=False)
    ax.set_title(f'x = {x_value}')
    ax.set_xlabel('Datasets')
    ax.set_ylabel('Accuracy')

# Ajouter une légende globale
handles, labels = axs[-1].get_legend_handles_labels()
fig.legend(handles, labels, title='Unlearning Methods', bbox_to_anchor=(1.05, 0.5), loc='center left')

plt.tight_layout()
plt.show()

# %%
grouped_df

# %%
# On remarque 2nd order est un bon compromis par rapport aux retraining et le SISA.

# %%
folders = ['Results_Adult/gradient_residual_results.csv', 'Results_Drebin/gradient_residual_results.csv', 'Results_Enron/gradient_residual_results.csv']

# Initialize an empty list to store individual DataFrames
dfs = []

# Iterate over the file paths and read each CSV into a DataFrame
for f in folders:
    df = pd.read_csv(f)
    
    # Extract dataset name from the file path
    dataset_name = f.split('_')[1].split('/')[0]
    
    # Update the dataset name with the combination type
    df['Datasets'] = dataset_name + '_' + df['x'].astype(str)
    
    # Append the DataFrame to the list
    dfs.append(df)

# Combine all the DataFrames into a single DataFrame
combined_df = pd.concat(dfs, ignore_index=True)

# Display the combined DataFrame
print(combined_df)
# Regrouper par 'x'
grouped_df = combined_df.groupby('x')

# Créer les sous-graphes
fig, axs = plt.subplots(1, len(grouped_df), figsize=(20, 8), sharey=True)

# Couleurs des barres pour chaque méthode
colors = ['b', 'g', 'r', 'c', 'm', 'y']

# Tracer les barres pour chaque groupe de 'x'
for (x_value, group), ax in zip(grouped_df, axs):
    group = group.set_index('Datasets')
    group.drop('x', axis=1, inplace=True)
    group.plot(kind='bar', ax=ax, color=colors, legend=False)
    ax.set_title(f'x = {x_value}')
    ax.set_xlabel('Datasets')
    ax.set_ylabel('Residual')

# Ajouter une légende globale
handles, labels = axs[-1].get_legend_handles_labels()
fig.legend(handles, labels, title='Unlearning Methods', bbox_to_anchor=(1.05, 0.5), loc='center left')

plt.tight_layout()
plt.show()
# Out:
#      x          DP  Finetuning   1st-Order  2nd-Order    Datasets
# 0   10  532.161078  533.297643  508.537692  88.524036    Adult_10
# 1   10    3.190370    5.325120    3.123479   0.047655   Drebin_10
# 2   50    4.427259    7.024341    4.361683   0.097467   Drebin_50
# 3  100   13.777695   16.877820   13.447541   0.710777  Drebin_100
# 4   10    5.669748    5.517625    5.596742   0.094828    Enron_10
# 5   50   14.264385   14.063334   14.051987   0.320178    Enron_50
# 6  100   26.519162   26.189357   26.096373   0.878948   Enron_100

# %%
csv_file = 'unlearning_performance_metrics.csv'
perfomance_metrics = pd.read_csv(csv_file)
fig, ax = plt.subplots(figsize=(14, 8))
ax.bar(perfomance_metrics['Dataset'], perfomance_metrics['Gradient_Residual_Time'], label='Gradient Residual Time')
ax.bar(perfomance_metrics['Dataset'], perfomance_metrics['Scatter_Experiments_Time'], bottom=perfomance_metrics['Gradient_Residual_Time'], label='Scatter Experiments Time')
# Ajouter des étiquettes et un titre
ax.set_xlabel('Dataset')
ax.set_ylabel('Time (seconds)')
ax.set_title('Computational Efficiency of Unlearning Methods')
ax.legend()

# Afficher le graphique
plt.tight_layout()
plt.show()

# %%
perfomance_metrics
# Out:
#   Dataset  Gradient_Residual_Time  Scatter_Experiments_Time
# 0  Drebin              594.693012                 27.201303
